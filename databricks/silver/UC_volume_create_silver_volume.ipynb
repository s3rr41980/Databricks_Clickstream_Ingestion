# %%
# This uses the 'catalog' variable from your _config
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {catalog}.clickstream_silver")
print(f"Schema {catalog}.clickstream_silver is ready.")

# %%
# Create the volume for your checkpoints
spark.sql(f"CREATE VOLUME IF NOT EXISTS {catalog}.clickstream_silver.checkpoints")
print(f"Managed Volume {catalog}.clickstream_silver.checkpoints is ready.")
