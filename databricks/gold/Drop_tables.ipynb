# %%
spark.sql("DROP TABLE IF EXISTS databricks_clickstream_dev.clickstream_gold.dim_geo")
spark.sql("DROP TABLE IF EXISTS databricks_clickstream_dev.clickstream_gold.dim_users")
spark.sql("DROP TABLE IF EXISTS databricks_clickstream_dev.clickstream_gold.dim_date")
spark.sql("DROP TABLE IF EXISTS databricks_clickstream_dev.clickstream_gold.fact_web_events")
