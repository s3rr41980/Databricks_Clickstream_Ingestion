# %%
# %sql
-- 1. Create the RAW Volume (Where your producer drops JSONs)
CREATE EXTERNAL VOLUME IF NOT EXISTS databricks_clickstream_dev.clickstream_bronze.raw
LOCATION 'abfss://raw@azuredarabricksstorage.dfs.core.windows.net/clickstream/'
COMMENT 'Landing zone for raw clickstream JSON files from Azure VM';

-- 2. Verify they were created
SHOW VOLUMES IN databricks_clickstream_project.clickstream_bronze;
