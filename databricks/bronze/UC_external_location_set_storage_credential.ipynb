# %%
# %sql
ALTER EXTERNAL LOCATION raw_clickstream_loc SET STORAGE CREDENTIAL storage_credential;

ALTER EXTERNAL LOCATION bronze_clickstream_loc SET STORAGE CREDENTIAL storage_credential;
ALTER EXTERNAL LOCATION checkpoint_clickstream_loc SET STORAGE CREDENTIAL storage_credential;

-- Only run this if 'databricks_clickstream_project' is an External Location 
-- and not just the name of the catalog or credential.
ALTER EXTERNAL LOCATION databricks_clickstream_project SET STORAGE CREDENTIAL storage_credential;
